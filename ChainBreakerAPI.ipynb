# %% [markdown]
# <img src = "https://chainbreaker-7e0c9.web.app/assets/img/hero-img.png" width = "400px">
#
# # Welcome to ChainBreaker API
#
# ---
#
# ChainBreaker Community consist in a team of academics, data scientists and human trafficking experts focused on collecting data from several online sexual services to combat human trafficking. You can easily access our data using our APIs. Visit our website <a href = "">here</a>. If it is the first time you are going to use our API, make sure you understand and agree with our terms and conditions.
#
# In this notebook, **you will learn to**:
# 1. Log into your account.
# 2. Change your password.
# 3. Request data from ChainBreaker API.
# 4. Logout.
# 5. Recover your password (in case you forgot it).

# %%
# Get ChainBreakerClient.
from client import ChainBreakerClient

# %%
# Create ChainBreakerClient instance.
client = ChainBreakerClient()

# %% [markdown]
# ### 1. Log into your account.
# ---
#
# In order to use ChainBreakerAPI you will need an account. Due to the privacy terms of our data it's not possible to offer a public version of our database. If you don't have an account please contact us and we will review your case. Make sure to present yourself and explain us why you want to have access to ChainBreaker data.

# %% [markdown]
# If you have an account, all you need to do is call <code>client.login()</code> function and enter your credentials.

# %%
# Login.
client.login()
# Out:
# "Hi Juan Cepeda! You are now connected to ChainBreaker API. Your current permission level is 'admin'. If you have any questions don't hesitate to contact us!"

# %%
client.get_account_info()
# Out:
# -- ChainBreaker Account Information --
#
# Name:  Juan Cepeda
# Email:  jecepedab@unal.edu.co
# Permission:  admin

# %% [markdown]
# ### 2. Change your password
#
# ---
#
# When you log into your account for the first time, is mandatory that you change your password. All you need to do is to use <code>client.change_password()</code> function.

# %%
client.change_password()
# Out:
# Old password:  ········
# New password:  ········
# Repeat new password:  ········
# 'Password updated!'

# %% [markdown]
# ### 3. Request data from ChainBreakerAPI.
#
# ---

# %%
# Function description.
help(client.get_ads)
# Out:
# Help on method get_ads in module client:
#
# get_ads(language='', website='') method of client.ChainBreakerClient instance
#     This function returns ads data from ChainBreaker Database.
#     - language can be: "spanish", "english" or "" (all).
#     - website can be:
#       - "mileroticos", "skokka" or "" (all) (for "spanish")
#       - "leolist" or "" (all) (for "english")

# %%
client.get_ads(language = "spanish", website = "skokka")
# Out:
#       language                                               link    id_page  \
# id_ad
# 12781  spanish  https://co.skokka.com/prepagos/cali/beso-negro...  co75xp1ta
# 12782  spanish  https://co.skokka.com/prepagos/medellin/rubia-...  co6psac2u
# 12783  spanish  https://co.skokka.com/prepagos/cartagena/rico-...  co4gthhc2
# 12784  spanish  https://co.skokka.com/prepagos/cali/soy-natali...  co1psmggx
# 12785  spanish  https://co.skokka.com/prepagos/villavicencio/v...  co6hx62av
# ...        ...                                                ...        ...
# 29985  spanish  https://co.skokka.com/escorts-masculinos/medel...  co97kgg6a
# 29986  spanish  https://co.skokka.com/escorts-masculinos/barra...  co6vexehs
# 29987  spanish  https://co.skokka.com/escorts-masculinos/santa...  co5ek8018
# 29988  spanish  https://co.skokka.com/escorts-masculinos/carta...  co3e5jp8s
# 29989  spanish  https://co.skokka.com/escorts-masculinos/medel...  co725tkuc
#
#                                                    title  \
# id_ad
# 12781  beso negro profundo anal bien arrecho dame tod...
# 12782      rubia joven traviesa muy complaciente para ti
# 12783  rico sexo oral ven y disfruta conmigo\ndiscret...
# 12784  soy natalia scort y webcam ardiente por videol...
# 12785  villavicencio hola soy camila una universitari...
# ...                                                  ...
# 29985  Joven, flaco, rico y con buen higiene. scort s...
# 29986         Me llamo john scott, pelado moreno tatuado
# 29987                     Chico caliente latino sexy hot
# 29988     Quiero ganas de que me den pero no tengo sitio
# 29989  Soy un chico atletico, educado dispuesto a com...
#
#                                                     text            category  \
# id_ad
# 12781  mi nombre es andrea una picara cautivadora de ...            prepagos
# 12782  hola mis amores mi nombre es karol soy una chi...            prepagos
# 12783  mi vida te ofrezcomi servicio presencial inclu...            prepagos
# 12784  hola te ofrezco una videollamada súper calient...            prepagos
# 12785  hermosa chica muy complaciente pie suabe cola ...            prepagos
# ...                                                  ...                 ...
# 29985  Joven flaco rico, scort masculino para mujeres...  escorts-masculinos
# 29986  Holasoy john scort, pelao moreno, tatuado de 1...  escorts-masculinos
# 29987  Soy dilan nuevo en la ciudad tengo 23 anos m a...  escorts-masculinos
# 29988  Hola quiero que me den soy un poco inexperto p...  escorts-masculinos
# 29989  Soy un chico atletico, educado dispuesto a com...  escorts-masculinos
#
#                            post_date verified_ad no_prepayment promoted_ad  \
# id_ad
# 12781  Wed, 19 May 2021 00:00:00 GMT        None          None        None
# 12782  Wed, 19 May 2021 00:00:00 GMT        None          None        None
# 12783  Wed, 19 May 2021 00:00:00 GMT        None          None        None
# 12784  Wed, 19 May 2021 00:00:00 GMT        None          None        None
# 12785  Wed, 19 May 2021 00:00:00 GMT        None          None        None
# ...                              ...         ...           ...         ...
# 29985  Fri, 11 Jun 2021 00:00:00 GMT        None          None        None
# 29986  Fri, 11 Jun 2021 00:00:00 GMT        None          None        None
# 29987  Fri, 11 Jun 2021 00:00:00 GMT        None          None        None
# 29988  Fri, 11 Jun 2021 00:00:00 GMT        None          None        None
# 29989  Fri, 11 Jun 2021 00:00:00 GMT        None          None        None
#
#        has_external_link external_website reviews_website website  \
# id_ad
# 12781              False             None            None  skokka
# 12782              False             None            None  skokka
# 12783              False             None            None  skokka
# 12784              False             None            None  skokka
# 12785              False             None            None  skokka
# ...                  ...              ...             ...     ...
# 29985              False             None            None  skokka
# 29986              False             None            None  skokka
# 29987              False             None            None  skokka
# 29988              False             None            None  skokka
# 29989              False             None            None  skokka
#
#                         extract_date
# id_ad
# 12781  Wed, 19 May 2021 14:10:53 GMT
# 12782  Wed, 19 May 2021 14:10:59 GMT
# 12783  Wed, 19 May 2021 14:11:04 GMT
# 12784  Wed, 19 May 2021 14:11:08 GMT
# 12785  Wed, 19 May 2021 14:11:14 GMT
# ...                              ...
# 29985  Fri, 11 Jun 2021 18:06:18 GMT
# 29986  Fri, 11 Jun 2021 18:06:22 GMT
# 29987  Fri, 11 Jun 2021 18:06:27 GMT
# 29988  Fri, 11 Jun 2021 18:06:33 GMT
# 29989  Fri, 11 Jun 2021 18:06:36 GMT
#
# [8024 rows x 15 columns]

# %% [markdown]
# #### 3.1 Get ChainBreaker Glossary.
#
# ---

# %%
# Function description.
help(client.get_glossary)
# Out:
# Help on method get_glossary in module client:
#
# get_glossary(domain='') method of client.ChainBreakerClient instance
#     This function returns the glossary of terms contained in ChainBreaker Database.
#     - domain can be: "sexual", "general" or "" (all).

# %%
# Get glossary.
client.get_glossary(domain="sexual")
# Out:
#          domain                 term  \
# id_term
# 1        sexual               Agency
# 2        sexual          Arrangement
# 3        sexual            Automatic
# 4        sexual         Backpage.com
# 5        sexual            Barracuda
# ...         ...                  ...
# 178      sexual                Wifey
# 179      sexual  Work the red carpet
# 180      sexual               Worker
# 181      sexual              Working
# 182      sexual         Working girl
#
#                                                 definition
# id_term
# 1        A company that manages calls, bookings, and ad...
# 2        In places where prostitution is legal, the dru...
# 3        A term denoting the victim’s automatic routine...
# 4        A classified ad website frequently used by tra...
# 5        Adult Service Provider whose sole purpose is t...
# ...                                                    ...
# 178            Victims of pimp partners who work together
# 179      Being trafficked in hotels when considered too...
# 180          Term used to objectify adult service provider
# 181      Engaged in active prostitution; The exchange w...
# 182          Term used to objectify adult service provider
#
# [182 rows x 3 columns]

# %% [markdown]
# #### 3.2 Get ChainBreaker Keywords.
#
# ---

# %%
# Function description.
help(client.get_keywords)
# Out:
# Help on method get_keywords in module client:
#
# get_keywords(language='') method of client.ChainBreakerClient instance
#     This function returns the set of keywords contained in ChainBreaker Database
#     - language can be: "english", "spanish", "portuguese", "russian" or "" (all).

# %%
client.get_keywords(language="english")
# Out:
#            language            keyword english_translation  \
# id_keyword
# 6           english      Soixante-neuf
# 7           english                  $
# 8           english                 $j
# 9           english                 $$
# 10          english                $$j
# ...             ...                ...                 ...
# 708         english  Trap House (Trap)
# 709         english              Track
# 710         english            Circuit
# 711         english            in-call
# 712         english           out-call
#
#                                                       meaning age_flag  \
# id_keyword
# 6                                                          69    False
# 7                                                         100    False
# 8                                                         100    False
# 9                                                         200    False
# 10                                                        200    False
# ...                                                       ...      ...
# 708         A place victims are kept or stay when not work...    False
# 709                                Area in which victims work    False
# 710         All the "tracks" in the country. Pimp takes vi...    False
# 711                A location where johns can go for services    False
# 712         A location where a victim will go to meet a john     False
#
#            trafficking_flag movement_flag
# id_keyword
# 6                      None         False
# 7                      None         False
# 8                      None         False
# 9                      None         False
# 10                     None         False
# ...                     ...           ...
# 708                    None          None
# 709                    None          None
# 710                    None          True
# 711                    None          None
# 712                    None          None
#
# [707 rows x 7 columns]

# %% [markdown]
# ### 4. Logout.
# ---
#
# Everytime you are done using ChainBreakerAPI, make sure to logout from your account. This is the better way to protect your account from pirates. All you need to do is to use <code>client.logout()</code> function.

# %%
client.logout()
# Out:
# Session closed.

# %% [markdown]
# ### 5. Recover your password
#
# ---

# %%
client.recover_password()
# Out:
# Email:  jecepedab@unal.edu.co
# Enter Recovery token  (check your email):  eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpZF91c2VyIjo0NywiZW1haWwiOiJqZWNlcGVkYWJAdW5hbC5lZHUuY28iLCJwZXJtaXNzaW9uIjoiYWRtaW4iLCJleHAiOjE2Mjk2ODQ0MjJ9.z6WjrUZKy2W6zyZ6as8QwrVKEyyX4eyMvK8bF29UGAA
# New password:  ········
# Repeat new password:  ········
# 'Password changed!'
